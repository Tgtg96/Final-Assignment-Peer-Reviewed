# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Taylor__
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I want to deepen my knowledge as an environmental scientist and build upon my current skills._

# %% [markdown]
# ### The following cell, will execute a desired output from an input scenario.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ---
#
# 1. List item #1
# 2. List item #2
#
# ---
#
# - Bulleted list #1
# - Bulleted list #2
#
# ---
